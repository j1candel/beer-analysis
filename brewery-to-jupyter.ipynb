# %%
#Import Modules
import psycopg2
import sqlalchemy as sal 
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Create engine path
engine = create_engine('postgres+psycopg2://postgres:T0nielt1gre@localhost:5432/beer_lovers')

#Connect engine path
conn = engine.connect()

# %%
#Choose table from data frame
breweries = pd.read_sql("SELECT * FROM breweries", conn)

categories = pd.read_sql("SELECT * FROM categories", conn)

reviewed_breweries_clean = pd.read_sql("SELECT * FROM reviewed_breweires_clean", conn)

reviewed_breweries = pd.read_sql("SELECT * FROM reviewed_breweries", conn)

# %%
breweries.head()
# Out:
#    id                                               name  \
# 0   1                              (512) Brewing Company
# 1   2                        21st Amendment Brewery Cafe
# 2   3  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij
# 3   4                                       Aass Brewery
# 4   5                                    Abbaye de Leffe
#
#                          address1 address2           city           state  \
# 0                 407 Radam, F200     None         Austin           Texas
# 1               563 Second Street     None  San Francisco      California
# 2                   Hoogstraat 2A     None        Beersel  Vlaams Brabant
# 3  Ole Steensgt. 10 Postboks 1530     None        Drammen            None
# 4                          Dinant     None         Dinant           Namur
#
#     code        country              phone  \
# 0  78745  United States       512.707.2337
# 1  94107  United States     1-415-369-0900
# ...

# %%
categories.head()
# Out:
#    id            cat_name
# 0  -1              Unique
# 1   1         British Ale
# 2   2           Irish Ale
# 3   3  North American Ale
# 4   4          German Ale

# %%
reviewed_breweries_clean.head()
# Out:
#    id     city state       beer_style  brewery_name  review_overall  beer_abv  \
# 0   4  Drammen  None  Euro Dark Lager  Aass Brewery             1.5       4.5
# 1   4  Drammen  None  German Pilsener  Aass Brewery             2.0       5.5
# 2   4  Drammen  None     Vienna Lager  Aass Brewery             2.0       6.5
# 3   4  Drammen  None  Euro Pale Lager  Aass Brewery             2.0       4.7
# 4   4  Drammen  None             Bock  Aass Brewery             2.0       6.5
#
#    review_aroma  review_appearance  review_taste  average_score
# 0           3.5                3.5           2.0           2.63
# 1           2.0                2.0           2.5           2.13
# 2           2.0                3.0           2.0           2.25
# 3           2.0                3.5           2.5           2.50
# 4           3.0                4.0           4.0           3.25

# %%
reviewed_breweries.head()
# Out:
#     id      city    state                brewery_name  review_overall  \
# 0  882  Savannah  Georgia  Moon River Brewing Company             3.5
# 1  882  Savannah  Georgia  Moon River Brewing Company             3.5
# 2  882  Savannah  Georgia  Moon River Brewing Company             4.0
# 3  882  Savannah  Georgia  Moon River Brewing Company             4.0
# 4  882  Savannah  Georgia  Moon River Brewing Company             4.0
#
#    review_aroma  review_appearance              beer_style  review_taste  \
# 0           3.5                3.0         American Porter           3.5
# 1           4.0                4.5  Scotch Ale / Wee Heavy           3.5
# 2           4.5                3.5            American IPA           4.0
# 3           3.5                4.0  Scotch Ale / Wee Heavy           3.5
# 4           3.5                3.0        Belgian Pale Ale           4.0
#
#               beer_name  beer_abv
# 0  The Captain's Porter       6.0
# 1  The Highland Stagger       NaN
# ...
